# %%
import pandas as pd

# %%
df = pd.read_csv('untidy.csv', sep=";")

# %%
df.head()
# Out:
#            Name  treatmenta  treatmentb
# 0    John Smith         NaN           2
# 1      Jand Doe        16.0          11
# 2  Mary Johnson         3.0           1

# %%
df.columns
# Out:
# Index(['Name', 'treatmenta', 'treatmentb'], dtype='object')

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# Name          3 non-null object
# treatmenta    2 non-null float64
# treatmentb    3 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 152.0+ bytes

# %%
df2 = pd.read_csv('dob_job.csv')
# Out:
# /home/admin123/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2.head()
# Out:
#        Job #  Doc #        Borough       House #  \
# 0  121577873      2      MANHATTAN  386
# 1  520129502      1  STATEN ISLAND  107
# 2  121601560      1      MANHATTAN  63
# 3  121601203      1      MANHATTAN  48
# 4  121601338      1      MANHATTAN  45
#
#                         Street Name  Block  Lot    Bin # Job Type Job Status  \
# 0  PARK AVENUE SOUTH                   857   38  1016890       A2          D
# 1  KNOX PLACE                          342    1  5161350       A3          A
# 2  WEST 131 STREET                    1729    9  1053831       A2          Q
# 3  WEST 25TH STREET                    826   69  1015610       A2          D
# 4  WEST 29 STREET                      831    7  1015754       A3          D
#
#             ...                         Owner's Last Name  \
# 0           ...            MIGLIORE
# 1           ...            BLUMENBERG
# 2           ...            MARKOWITZ
# 3           ...            CASALE
# 4           ...            LEE
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12846 entries, 0 to 12845
# Data columns (total 82 columns):
# Job #                           12846 non-null int64
# Doc #                           12846 non-null int64
# Borough                         12846 non-null object
# House #                         12846 non-null object
# Street Name                     12846 non-null object
# Block                           12846 non-null int64
# Lot                             12846 non-null int64
# Bin #                           12846 non-null int64
# Job Type                        12846 non-null object
# Job Status                      12846 non-null object
# Job Status Descrp               12846 non-null object
# Latest Action Date              12846 non-null object
# Building Type                   12846 non-null object
# Community - Board               12846 non-null object
# Cluster                         0 non-null float64
# ...

# %%
df2.describe()
# Out:
#               Job #         Doc #         Block           Lot         Bin #  \
# count  1.284600e+04  12846.000000  12846.000000  12846.000000  1.284600e+04
# mean   2.426788e+08      1.162930   2703.834735    623.303441  2.314997e+06
# std    1.312507e+08      0.514937   3143.002812   2000.934794  1.399062e+06
# min    1.036438e+08      1.000000      1.000000      0.000000  1.000003e+06
# 25%    1.216206e+08      1.000000    836.000000     12.000000  1.035728e+06
# 50%    2.202645e+08      1.000000   1411.500000     32.000000  2.004234e+06
# 75%    3.208652e+08      1.000000   3355.000000     59.000000  3.343823e+06
# max    5.400246e+08      9.000000  99999.000000   9078.000000  5.864852e+06
#
#        Cluster  PC Filed  Existing Zoning Sqft  Proposed Zoning Sqft  \
# count      0.0       0.0          1.284600e+04          1.284600e+04
# mean       NaN       NaN          1.439973e+03          2.007286e+03
# std        NaN       NaN          3.860757e+04          4.081570e+04
# ...

# %%
df2.columns
# Out:
# Index(['Job #', 'Doc #', 'Borough', 'House #', 'Street Name', 'Block', 'Lot',
#        'Bin #', 'Job Type', 'Job Status', 'Job Status Descrp',
#        'Latest Action Date', 'Building Type', 'Community - Board', 'Cluster',
#        'Landmarked', 'Adult Estab', 'Loft Board', 'City Owned', 'Little e',
#        'PC Filed', 'eFiling Filed', 'Plumbing', 'Mechanical', 'Boiler',
#        'Fuel Burning', 'Fuel Storage', 'Standpipe', 'Sprinkler', 'Fire Alarm',
#        'Equipment', 'Fire Suppression', 'Curb Cut', 'Other',
#        'Other Description', 'Applicant's First Name', 'Applicant's Last Name',
#        'Applicant Professional Title', 'Applicant License #',
#        'Professional Cert', 'Pre- Filing Date', 'Paid', 'Fully Paid',
#        'Assigned', 'Approved', 'Fully Permitted', 'Initial Cost',
#        'Total Est. Fee', 'Fee Status', 'Existing Zoning Sqft',
#        'Proposed Zoning Sqft', 'Horizontal Enlrgmt', 'Vertical Enlrgmt',
# ...

# %%
df2['Borough'].value_counts(dropna=False)
# Out:
# MANHATTAN        6310
# BROOKLYN         2866
# QUEENS           2121
# BRONX             974
# STATEN ISLAND     575
# Name: Borough, dtype: int64

# %%
df2['State'].value_counts(dropna=False)
# Out:
# NY    12391
# NJ      241
# PA       38
# CA       20
# OH       19
# FL       17
# IL       17
# CT       16
# TX       13
# TN       10
# MD        7
# DC        7
# KS        6
# MA        6
# GA        6
# VA        5
# CO        4
# SC        3
# WI        3
# MN        3
# AZ        3
# RI        2
# NC        2
# UT        2
# VT        1
# MI        1
# NM        1
# IN        1
# WA        1
# Name: State, dtype: int64

# %%
df2['Site Fill'].value_counts(dropna=False)
# Out:
# NOT APPLICABLE                              7806
# NaN                                         4205
# ON-SITE                                      519
# OFF-SITE                                     186
# USE UNDER 300 CU.YD                          130
# Name: Site Fill, dtype: int64

# %%
vcnt = df2['Site Fill'].value_counts(dropna=False)
if vcnt[0]==1:
    print('True')
else:
    print('False')
# Out:
# False

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## abc

# %%
df2['Street Frontage'].plot('hist')

# %%
plt.show()

# %%
Scatter_plot = df2.plot(kind='scatter', x='Existing Height', y='Proposed Height')

# %%
df2['Street Frontage'].describe()
# Out:
# count    12846.000000
# mean         3.069360
# std         37.246034
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       3160.000000
# Name: Street Frontage, dtype: float64

# %%
df2[df2['Street Frontage']>1000]
# Out:
#            Job #  Doc #    Borough       House #  \
# 10459  121329044      1  MANHATTAN  601S
#
#                             Street Name  Block   Lot    Bin # Job Type  \
# 10459  WEST 130TH STREET                  1997  8009  1088867       A3
#
#       Job Status           ...                         Owner's Last Name  \
# 10459          A           ...            PITRUZZELLO
#
#                   Owner's Business Name Owner's House Number  \
# 10459  COLUMBIA UNIVERSITY FACILITIES           615
#
#                Owner'sHouse Street Name            City  State    Zip  \
# 10459  WEST 131ST STREET                 NEW YORK           NY  10027
#
#       Owner'sPhone #                                    Job Description  \
# 10459     2128542195  BUILDERS PAVEMENT PLAN. FILE IN CONJUNCTION WI...
#
#                    DOBRunDate
# 10459  06/05/2013 12:00:00 AM
#
# [1 rows x 82 columns]

# %%
df2['Existing Zoning Sqft'].plot(kind='hist', rot='70', logx=False, logy=True)

# %%
df2.boxplot(column='Existing Height', by='Borough')

# %%
import seaborn as sns

# %%
sns.boxplot(y='Existing Height', x='Borough', data=df2)
plt.show()

# %%
df2.plot(kind='scatter', x='Existing Height', y='Proposed Height', rot=60)

# %%
df_subset = df2[df2['Existing Height']<10]

# %%
df_subset.plot(kind="scatter", x='Existing Height', y='Proposed Height', rot=60)

# %%
df_ut = pd.read_csv('untidy.csv', sep=";")
df_ut
# Out:
#            Name  treatmenta  treatmentb
# 0    John Smith         NaN           2
# 1      Jand Doe        16.0          11
# 2  Mary Johnson         3.0           1

# %%
dft = pd.melt(frame=df_ut, id_vars=['Name'], value_vars=['treatmenta', 'treatmentb'], var_name='Treatment', value_name='Frequency')
dft
# Out:
#            Name   Treatment  Frequency
# 0    John Smith  treatmenta        NaN
# 1      Jand Doe  treatmenta       16.0
# 2  Mary Johnson  treatmenta        3.0
# 3    John Smith  treatmentb        2.0
# 4      Jand Doe  treatmentb       11.0
# 5  Mary Johnson  treatmentb        1.0

# %%
dft.pivot(index='Name', columns='Treatment', values='Frequency')
# Out:
# Treatment     treatmenta  treatmentb
# Name
# Jand Doe            16.0        11.0
# John Smith           NaN         2.0
# Mary Johnson         3.0         1.0

# %%
import numpy  as np

# %%
dft.pivot_table(index='Name', columns='Treatment', values='Frequency', aggfunc=np.sum)
# Out:
# Treatment     treatmenta  treatmentb
# Name
# Jand Doe            16.0        11.0
# John Smith           0.0         2.0
# Mary Johnson         3.0         1.0

# %%
df2v = pd.read_csv('untidy_2v.csv', sep=';')

# %%
df2v
# Out:
#   Country  Year  m014  m1435  m3660  f014  f1435  f3660
# 0       A  2000     3    5.0      7     4      5      6
# 1       B  2000     3    6.0      9     7      4      2
# 2       C  2000     1    7.0      6     2      4      7
# 3       D  2000     5    NaN      4     7      5      6
# 4       E  2000     8    9.0      3     6      2      1
# 5       F  2000     5    6.0      9     8      7      1
# 6       A  2001     5    5.0      4     6      3      2
# 7       B  2001     9    2.0      7     4      8      6

# %%
df2v_melt = df2v.melt(id_vars=['Country', 'Year'])
df2v_melt.head()
# Out:
#   Country  Year variable  value
# 0       A  2000     m014    3.0
# 1       B  2000     m014    3.0
# 2       C  2000     m014    1.0
# 3       D  2000     m014    5.0
# 4       E  2000     m014    8.0

# %%
df2v_melt['Sex'] = df2v_melt['variable'].str[0]
df2v_melt['age'] = df2v_melt['variable'].str[1:]
df2v_melt.head()
# Out:
#   Country  Year variable  value Sex  age
# 0       A  2000     m014    3.0   m  014
# 1       B  2000     m014    3.0   m  014
# 2       C  2000     m014    1.0   m  014
# 3       D  2000     m014    5.0   m  014
# 4       E  2000     m014    8.0   m  014

# %%
dftop = df2.head()

# %%
dfbot = df2.tail()

# %%
dfcomb = pd.concat([dftop, dfbot])
dfcomb
# Out:
#            Job #  Doc #        Borough       House #  \
# 0      121577873      2      MANHATTAN  386
# 1      520129502      1  STATEN ISLAND  107
# 2      121601560      1      MANHATTAN  63
# 3      121601203      1      MANHATTAN  48
# 4      121601338      1      MANHATTAN  45
# 12841  520143988      1  STATEN ISLAND  8
# 12842  121613833      1      MANHATTAN  724
# 12843  121681260      1      MANHATTAN  350
# 12844  320771704      1       BROOKLYN  499
# 12845  520143951      1  STATEN ISLAND  1755
#
#                             Street Name  Block  Lot    Bin # Job Type  \
# 0      PARK AVENUE SOUTH                   857   38  1016890       A2
# 1      KNOX PLACE                          342    1  5161350       A3
# 2      WEST 131 STREET                    1729    9  1053831       A2
# 3      WEST 25TH STREET                    826   69  1015610       A2
# 4      WEST 29 STREET                      831    7  1015754       A3
# ...

# %%
dfcomb2 = pd.concat([dftop,dfbot],ignore_index=True)
dfcomb2
# Out:
#        Job #  Doc #        Borough       House #  \
# 0  121577873      2      MANHATTAN  386
# 1  520129502      1  STATEN ISLAND  107
# 2  121601560      1      MANHATTAN  63
# 3  121601203      1      MANHATTAN  48
# 4  121601338      1      MANHATTAN  45
# 5  520143988      1  STATEN ISLAND  8
# 6  121613833      1      MANHATTAN  724
# 7  121681260      1      MANHATTAN  350
# 8  320771704      1       BROOKLYN  499
# 9  520143951      1  STATEN ISLAND  1755
#
#                         Street Name  Block  Lot    Bin # Job Type Job Status  \
# 0  PARK AVENUE SOUTH                   857   38  1016890       A2          D
# 1  KNOX PLACE                          342    1  5161350       A3          A
# 2  WEST 131 STREET                    1729    9  1053831       A2          Q
# 3  WEST 25TH STREET                    826   69  1015610       A2          D
# 4  WEST 29 STREET                      831    7  1015754       A3          D
# ...

# %%
dfcol1 = df2["Borough"]
dfcol2 = df2['Block']
dfcol3 = df2["Lot"]

dfcombCol = pd.concat([dfcol1, dfcol2, dfcol3], axis=1)
dfcombCol.head()
# Out:
#          Borough  Block  Lot
# 0      MANHATTAN    857   38
# 1  STATEN ISLAND    342    1
# 2      MANHATTAN   1729    9
# 3      MANHATTAN    826   69
# 4      MANHATTAN    831    7

# %%
import glob
lstfile = glob.glob("*.csv")

# %%
lstfile
# Out:
# ['dob_job.csv', 'untidy_2v.csv', 'untidy.csv', 'dob_job (1).csv']

# %%
df_lst = []
for fl in lstfile:
    dfl = pd.read_csv(fl)
    df_lst.append(dfl)

df_lst[0].head()
# Out:
#        Job #  Doc #        Borough       House #  \
# 0  121577873      2      MANHATTAN  386
# 1  520129502      1  STATEN ISLAND  107
# 2  121601560      1      MANHATTAN  63
# 3  121601203      1      MANHATTAN  48
# 4  121601338      1      MANHATTAN  45
#
#                         Street Name  Block  Lot    Bin # Job Type Job Status  \
# 0  PARK AVENUE SOUTH                   857   38  1016890       A2          D
# 1  KNOX PLACE                          342    1  5161350       A3          A
# 2  WEST 131 STREET                    1729    9  1053831       A2          Q
# 3  WEST 25TH STREET                    826   69  1015610       A2          D
# 4  WEST 29 STREET                      831    7  1015754       A3          D
#
#             ...                         Owner's Last Name  \
# 0           ...            MIGLIORE
# 1           ...            BLUMENBERG
# 2           ...            MARKOWITZ
# 3           ...            CASALE
# 4           ...            LEE
#
# ...

# %%
df.dtypes
# Out:
# Name           object
# treatmenta    float64
# treatmentb      int64
# dtype: object

# %%
df['Name'] = df['Name'].astype('str')

# %%
df.dtypes
# Out:
# Name           object
# treatmenta    float64
# treatmentb      int64
# dtype: object

# %%
df['treatmentb'] = df['treatmentb'].astype('str')
df.dtypes
# Out:
# Name           object
# treatmenta    float64
# treatmentb     object
# dtype: object

# %%
## CLEANING

# %%
dfcombCol.head()
# Out:
#          Borough  Block  Lot
# 0      MANHATTAN    857   38
# 1  STATEN ISLAND    342    1
# 2      MANHATTAN   1729    9
# 3      MANHATTAN    826   69
# 4      MANHATTAN    831    7

# %%
df_subset
# Out:
#            Job #  Doc #        Borough       House #  \
# 0      121577873      2      MANHATTAN  386
# 1      520129502      1  STATEN ISLAND  107
# 26     121601249      3      MANHATTAN  150
# 32     420805597      2         QUEENS  149-57
# 41     520129389      1  STATEN ISLAND  25
# 42     402890403      4         QUEENS  147-36
# 43     520129398      1  STATEN ISLAND  29
# 51     520129352      1  STATEN ISLAND  24
# 64     121577873      3      MANHATTAN  386
# 65     121598280      3      MANHATTAN  575
# 72     520129012      1  STATEN ISLAND  547
# 73     520129370      1  STATEN ISLAND  21
# 74     520129325      1  STATEN ISLAND  59
# 77     121603470      1      MANHATTAN  199
# 79     121601249      2      MANHATTAN  150
# 84     121598280      2      MANHATTAN  575
# 85     121600678      2      MANHATTAN  249
# 89     320726880      2       BROOKLYN  98
# 92     520129414      1  STATEN ISLAND  37
# 93     520129343      1  STATEN ISLAND  28
# ...

# %%
df
# Out:
#            Name  treatmenta treatmentb
# 0    John Smith         NaN          2
# 1      Jand Doe        16.0         11
# 2  Mary Johnson         3.0          1

# %%
df2
# Out:
#            Job #  Doc #        Borough       House #  \
# 0      121577873      2      MANHATTAN  386
# 1      520129502      1  STATEN ISLAND  107
# 2      121601560      1      MANHATTAN  63
# 3      121601203      1      MANHATTAN  48
# 4      121601338      1      MANHATTAN  45
# 5      121589753      1      MANHATTAN  350
# 6      320738001      1       BROOKLYN  437
# 7      121601374      1      MANHATTAN  99
# 8      121583054      1      MANHATTAN  1355
# 9      121601392      1      MANHATTAN  1
# 10     121601169      1      MANHATTAN  591
# 11     420828206      1         QUEENS  33-14
# 12     420828493      1         QUEENS  147-01
# 13     440075142      1         QUEENS  150-15
# 14     420836723      1         QUEENS  34-20
# 15     121584525      1      MANHATTAN  440
# 16     121600311      1      MANHATTAN  535
# 17     320744290      1       BROOKLYN  948
# 18     320744557      1       BROOKLYN  50
# 19     320744370      1       BROOKLYN  875
# ...

# %%
# Out:
# Index(['Job #', 'Doc #', 'Borough', 'House #', 'Street Name', 'Block', 'Lot',
#        'Bin #', 'Job Type', 'Job Status', 'Job Status Descrp',
#        'Latest Action Date', 'Building Type', 'Community - Board', 'Cluster',
#        'Landmarked', 'Adult Estab', 'Loft Board', 'City Owned', 'Little e',
#        'PC Filed', 'eFiling Filed', 'Plumbing', 'Mechanical', 'Boiler',
#        'Fuel Burning', 'Fuel Storage', 'Standpipe', 'Sprinkler', 'Fire Alarm',
#        'Equipment', 'Fire Suppression', 'Curb Cut', 'Other',
#        'Other Description', 'Applicant's First Name', 'Applicant's Last Name',
#        'Applicant Professional Title', 'Applicant License #',
#        'Professional Cert', 'Pre- Filing Date', 'Paid', 'Fully Paid',
#        'Assigned', 'Approved', 'Fully Permitted', 'Initial Cost',
#        'Total Est. Fee', 'Fee Status', 'Existing Zoning Sqft',
#        'Proposed Zoning Sqft', 'Horizontal Enlrgmt', 'Vertical Enlrgmt',
# ...
